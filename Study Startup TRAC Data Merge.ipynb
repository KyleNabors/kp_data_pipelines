# %%
import pandas as pd

# %%
trac_raw = pd.read_json(r"J:\TRAC\TRAC_Data.json", encoding="utf-16")

# expand the nested dicts into a new DataFrame
trac = pd.json_normalize(trac_raw["TRAC_Data"])

# keep the original index if needed
trac.index = trac_raw.index

# inspect
trac.info()
trac.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8171 entries, 0 to 8170
# Data columns (total 38 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   StudyId                               8171 non-null   int64
#  1   AgreementId                           8171 non-null   int64
#  2   SequenceNum                           8171 non-null   object
#  3   RegionDesc                            8171 non-null   object
#  4   StudyTitle                            8171 non-null   object
#  5   PI                                    8171 non-null   object
#  6   ProjectID                             8171 non-null   object
#  7   FundingTypeDesc                       8171 non-null   object
#  8   FundingSourceDesc                     8171 non-null   object
#  9   KPRecipientTypeDesc                   8171 non-null   object
#  10  ReferenceNum                          8171 non-null   object
# ...

# %%
# from pandasql import sqldf

# new_trac = sqldf("SELECT * FROM trac")
