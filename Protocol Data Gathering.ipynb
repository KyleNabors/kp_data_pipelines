# %%
import pandas as pd

# %%
protocol_folder = Path(r"C:\Users\O304312\Documents\Protocols")
pi_folders = Path(r"L:\CTP_CLINICAL_TRIALS_PROGRAM\CTP Cases")

# %%
for folder in pi_folders.iterdir():
    subfolder = folder / "Protocol"
